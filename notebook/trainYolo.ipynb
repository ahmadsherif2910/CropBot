# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")

# %%
model.train(data = "../dataset/data.yaml",epochs = 100,imgsz = 640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.170 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.169  Python-3.13.2 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i7-13620H)
# ...

# %%
import os
print(os.listdir("runs/detect/train5/weights"))
# Out:
# ['best.pt', 'last.pt']

# %%
from ultralytics import YOLO
model = YOLO("runs/detect/train5/weights/last.pt")

# %%
results = model("../dataset/images/train/20250710123053_001.jpg",show = True)
# Out:
# image 1/1 c:\ahmad\Programming\Python\projects\photoSplitProgram\notebook\..\dataset\images\train\20250710123053_001.jpg: 640x480 (no detections), 41.6ms
# Speed: 1.9ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)

# %%
from IPython.display import Image
Image("runs/detect/train5/results.png")

# %%
from ultralytics import YOLO
model = YOLO("runs/detect/train5/weights/best.pt")
results = model.predict(source=r"C:\ahmad\Programming\Python\projects\photoSplitProgram\photos\20250710132523_001.jpg", save=True, conf=0.02)
# Out:
# image 1/1 C:\ahmad\Programming\Python\projects\photoSplitProgram\photos\20250710132523_001.jpg: 640x480 1 photo, 46.2ms
# Speed: 2.0ms preprocess, 46.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\detect\predict15

# %%
boxes = results[0].boxes

if boxes is not None and boxes.shape[0] > 0:
    print("✅ Detections found!")
    print("Bounding boxes (xyxy):", boxes.xyxy)
    print("Confidences:", boxes.conf)
    print("Class indices:", boxes.cls)
else:
    print("❌ No detections found.")
# Out:
# ✅ Detections found!
# Bounding boxes (xyxy): tensor([[ 616.9518, 2180.0020, 2223.6716, 3300.8452]])
# Confidences: tensor([0.0355])
# Class indices: tensor([0.])
